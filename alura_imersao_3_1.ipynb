# %% [markdown]
# <a href="https://colab.research.google.com/github/emerson-diego/ImersaoDadosAlura-3/blob/main/alura_imersao_3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# No campo abaixo temos o que chamamos de célula. Na célula nós podemos digitar textos, cálculos e códigos.

# %%
10 + 10
# Out:
# 20

# %% [markdown]
# Após eu introduzir o que eu quero na célula eu vou rodar esse conteúdo. Para isso podemos usar o atalho SHIFT + ENTER, ou até mesmo clicar no símbolo de play no canto esquerdo da célula.

# %%
'emerson'
# Out:
# 'emerson'

# %%
#importa o dataframe

import pandas as pd

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head() # 5 primeiras linhas
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
dados.shape # número de linhas x colunas
# Out:
# (23814, 877)

# %%
dados['tratamento'] # mostra só a uma série (coluna)
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].unique() # dados únicos
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %%
dados['tratamento'].value_counts() #com controle = sem droga
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %%
####Desafio 3

dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.pie()

# %% [markdown]
# ####Além de identificar a quantidade de horas observadas, nós não conseguimos extrair mais nenhuma informação desse gráfico. Inclusive, nós temos uma espécie de regrinha, que diz que quando formos fazer algum tipo de análise, procurarmos evitar o uso de gráficos que nos remetem a comida, como por exemplo: rosca, pizza, torta, e assim por diante.

# %%
dados['tempo'].value_counts().plot.bar()

# %%
dados['g-0'] > 0
# Out:
# 0         True
# 1         True
# 2         True
# 3        False
# 4        False
#          ...
# 23809     True
# 23810    False
# 23811     True
# 23812     True
# 23813    False
# Name: g-0, Length: 23814, dtype: bool

# %% [markdown]
# Na coluna g-0, nós temos alguns valores dentro de um intervalo definido. Para não termos valores muito distantes entre si, é bastante comum no meio científico que haja uma normalização dos resultados, para criamos um intervalo que não seja tão grande, em que o meio dessa distribuição seja o 0.

# %%
dados[dados['g-0'] > 0]
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6      id_001bd861f     com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23807  id_fff7e6992     com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444     com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# ##Desafios
#
# ###Desafio 01: Investigar por que a classe tratamento é tão desbalanceada?
#
# ###Desafio 02: Plotar as 5 últimas linhas da tabela
#
# ###Desafio 03: Proporção das classes de tratamento.
#
# ###Desafio 04: Quantos tipos de drogas foram investigados.
#
# ###Desafio 05: Procurar na documentação o método query(pandas)
#
# ###Desafio 06: Renomear as colunas tirando o hífen.
#
# ###Desafio 07: Deixar os gráficos bonitões (título, label) (Matplotlib)
#
# ###Desafio 08: Resumo do que você aprendeu com os dados

# %% [markdown]
# ###Desafio 01: Investigar por que a classe tratamento é tão desbalanceada?

# %%
dados['tratamento'].value_counts(normalize = True)
# Em experimentos só há necessidade de um grupo controle, independente da quantidade de tratamentos/drogas a serem testadas.
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# Aqui vemos que temos certca de 8% das amostras que são apenas controle.

# %% [markdown]
# Dependendo o tipo de pesquisa é possível usar o mesmo controle para mais de um caso. Repare que o grupo de controle é um grupo onde não estamos aplicando o efeito de uma determinada droga. Então, esse mesmo grupo pode ser utilizado como controle para cada uma das drogas estudadas.
#
# Um ponto relevante da base de dados que estamos trabalhando é que todos os dados de controle estão relacionados ao estudo de apenas uma droga.

# %%
print(f"Total de dados {len(dados['id'])}\n")
print(f"Quantidade de drogas {len(dados.groupby(['droga', 'tratamento']).count()['id'])}\n")
display(dados.query('tratamento == "com_controle"').value_counts('droga'))
print()
display(dados.query('droga == "cacb2b860"').value_counts('tratamento'))
print()
# Out:
# Total de dados 23814
#
# Quantidade de drogas 3289
# droga
# cacb2b860    1866
# dtype: int64
# tratamento
# com_controle    1866
# dtype: int64

# %%
dados_controle = dados[dados['tratamento']=='com_controle']
print(dados_controle.groupby(['dose']).size())
print(dados_controle.groupby(['tempo']).size())
print(dados_controle.groupby(['droga']).size())
# Out:
# dose
# D1    951
# D2    915
# dtype: int64
# tempo
# 24    606
# 48    648
# 72    612
# dtype: int64
# droga
# cacb2b860    1866
# dtype: int64

# %% [markdown]
# Vemos então que todos os dados de controle dizem a respeito de uma droga 'cacb2b860', que tem o mesmo significado de dados['tratamento']=='com_controle', e que foi dividido igualmente para as doses D1 e D2 e entre os tempos 24,48 e 72. Imagino que foi feito dessa forma para se diminuir o enviesamento dos dados. Investigando agora os dados com drogas.

# %%
dados_droga = dados[dados['tratamento']=='com_droga']
print(dados_droga.groupby(['dose']).size())
print(dados_droga.groupby(['tempo']).size())
print(dados_droga.groupby(['droga']).size())
# Out:
# dose
# D1    11196
# D2    10752
# dtype: int64
# tempo
# 24    7166
# 48    7602
# 72    7180
# dtype: int64
# droga
# 00199ff52     6
# 00251fc41     6
# 00321ea80    12
# 0034c0847     6
# 0060e686f     6
#              ..
# ff9565933     6
# ffd66e220     6
# ffe357f8f     1
# ffed8e1c9     6
# fff7d208d     6
# Length: 3288, dtype: int64

# %%
dados_droga['droga'].value_counts()
# Out:
# 87d714366    718
# 9f80f3f77    246
# 8b87a7a83    203
# 5628cb3ee    202
# d08af5d4b    196
#             ...
# d70cdde82      1
# a9bc2c549      1
# c5ffd58ca      1
# 35519ef6d      1
# f0d1b8dbc      1
# Name: droga, Length: 3288, dtype: int64

# %% [markdown]
# Aqui comprovamos que há drogas que foram aplicadas muito mais do que as outras, mas por que?

# %%
print(dados_droga[dados_droga['droga']=='87d714366'].groupby(['tempo']).size())
print(dados_droga[dados_droga['droga']=='87d714366'].groupby(['dose']).size())

# %% [markdown]
# O número de doses e tempo continua equilibrado para cada droga, mas e para as drogas aplicadas apenas uma vez?

# %%
print(dados_droga[dados_droga['droga']=='f49a73cd5'].groupby(['tempo']).size())
print(dados_droga[dados_droga['droga']=='f49a73cd5'].groupby(['dose']).size())
# Out:
# tempo
# 48    1
# dtype: int64
# dose
# D1    1
# dtype: int64

# %% [markdown]
# Foram investigadas apenas para uma dose e um tempo.

# %% [markdown]
# ###Desafio 02: Plotar as 5 últimas linhas da tabela

# %% [markdown]
# Assim como com a função '.head()' a função '.tail()' tem como default imprimir as 5 últimas linhas, para mudar essa valor para menos ou mais linhas basta adicionar o número no argumento. Por exemplo, para imprimir as últimas 10 linhas, usaria-se 'dados.tail(10)'.

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# Outra opção seria usar o seguinte comando:

# %%
dados[-5:]
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# ###Desafio 03: Proporção das classes de tratamento.

# %% [markdown]
# Como explicado na aula, a proporção é feita através do argumento 'normalize' na função '.value_counts()' que é um booleano que pode receber True ou False, sendo que em sua configuração default está em False.

# %%
dados['tratamento'].value_counts(normalize=True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['tratamento'].value_counts().plot.bar()

# %% [markdown]
# ### Desafio 04: Quantos tipos de drogas foram investigados.
#
# ---

# %% [markdown]
# Desafio 04
# Para invesatigar o número de drogas, foi adotado a função '.describe()'

# %%
dados.describe()
# Out:
#               tempo            g0  ...           c98           c99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %% [markdown]
# Com esse resultado vemos todas as colunas que apresentam valores numéricos, ou seja, a coluna 'droga' que tem o nome das drogas utilizadas, não teremos informações estatísticas.

# %%
dados['droga'].describe()
# Out:
# count         23814
# unique         3289
# top       cacb2b860
# freq           1866
# Name: droga, dtype: object

# %% [markdown]
# Ao especificar a coluna, podemos obter algumas informações estatísticas. Como o número de drogas (unique), a quantidade de medidas (count), a droga mais utilizada (top) e sua frequência (1866), podemos checar essa informação através da formula abaixo:

# %%
(dados['droga']=='cacb2b860').value_counts()
# Out:
# False    21948
# True      1866
# Name: droga, dtype: int64

# %% [markdown]
# Fazendo o mesmo para toda a coluna de drogas podemos ver quais foram investigadas e qual frequência.

# %%
(dados['droga']).value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# 18a406358       1
# 98c94f9b9       1
# 4a8eda087       1
# dd4a96d16       1
# f0d1b8dbc       1
# Name: droga, Length: 3289, dtype: int64

# %% [markdown]
# Aqui podemos ver que algumas drogas foram utilizadas apenas uma vez. Vamos investigar a droga 'f49a73cd5'.

# %%
dados[dados['droga']=='f49a73cd5']
# Out:
#                  id tratamento  tempo dose  ...     c96     c97     c98     c99
# 23006  id_f711197c3  com_droga     48   D1  ... -0.7765  0.1564 -0.2462 -0.9312
#
# [1 rows x 877 columns]

# %% [markdown]
# Outras formas de cálculo para o desafio

# %%
dados.droga.shape
# Out:
# (23814,)

# %%
dados.droga.nunique() #quantidade de valores únicos por célula
# Out:
# 3289

# %%
dados.droga.drop_duplicates().count()
# Out:
# 3289

# %%
len(dados.droga.unique())
# Out:
# 3289

# %%
dados['droga'].unique().shape[0]
# Out:
# 3289

# %%
dados.droga.value_counts().head().plot.bar()

# %% [markdown]
# ###Desafio 05: Procurar na documentação o método query(pandas)

# %% [markdown]
# Essa lib não trabalha bem com alguns caracteres existentes no nome da coluna, como "-": https://medium.com/horadecodar/como-usar-o-query-do-pandas-fdf4a00727dc

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html

# %%
dados.query('tempo > 24')
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23806  id_fff790a17     com_droga     48   D2  ...  1.2630  0.7823 -0.6947  0.7277
# 23807  id_fff7e6992     com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444     com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
dados.query('tempo in [24,72] & dose == "D1"')
# Out:
#                  id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 5      id_001762a82  com_droga     24   D1  ...  1.2120  0.3765  0.7848  1.3990
# 14     id_002d31e2c  com_droga     72   D1  ... -8.1330 -4.3170 -6.2390  0.9477
# 22     id_003d4b6f0  com_droga     72   D1  ...  0.7287 -0.0168 -0.3555 -0.0509
# ...             ...        ...    ...  ...  ...     ...     ...     ...     ...
# 23802  id_fff3976bd  com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23804  id_fff506720  com_droga     24   D1  ... -0.4097  0.2282 -0.3213 -0.0836
# 23808  id_fff8c2444  com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23812  id_fffcb9e7c  com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b  com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# ...

# %%
dados_droga = dados[dados['tratamento']=='com_droga']
dados_drogamais = dados_droga[dados_droga['droga']=='87d714366']
dados_drogamais.shape
# Out:
# (718, 877)

# %%
dados_drogamais.query('g0 > g1').shape
# Out:
# (714, 877)

# %% [markdown]
# Ou seja, aplicando o filtro de g0>g1, temos que dos 718 casos da droga, 714 obedecem a essa regra. Vamos realizar mais filtros.

# %%
(dados_drogamais.query('g0 > g1')).query('g0 > g2').shape
# Out:
# (687, 877)

# %% [markdown]
# Reduzimos ainda mais, vendo que, de todas as 718 aplicações da droga '87d714366', 714 tem g0>g1 e dessas 687 tem g0>g2.

# %% [markdown]
# ###Desafio 06: Renomear as colunas tirando o hífen.

# %%
dados.columns
# Out:
# Index(['id', 'tratamento', 'tempo', 'dose', 'droga', 'g0', 'g1', 'g2', 'g3',
#        'g4',
#        ...
#        'c90', 'c91', 'c92', 'c93', 'c94', 'c95', 'c96', 'c97', 'c98', 'c99'],
#       dtype='object', length=877)

# %%
dados.columns = dados.columns.str.replace('-','')
dados
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.query('g0 > 0')
# Out:
#                  id    tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6      id_001bd861f     com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23807  id_fff7e6992     com_droga     48   D1  ...  0.3738  0.8636  0.4494  0.1218
# 23808  id_fff8c2444     com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
dados.query('g0 > 0').g0.value_counts()
# Out:
# 10.0000    14
# 0.1947      8
# 1.1520      8
# 1.1130      8
# 1.1410      8
#            ..
# 0.7806      1
# 5.7980      1
# 6.3840      1
# 5.8010      1
# 0.0852      1
# Name: g0, Length: 7492, dtype: int64

# %% [markdown]
# ###Desafio 07: Deixar os gráficos bonitões (título, label) (Matplotlib)

# %% [markdown]
# Para poder deixar os gráficos com mais informações, busca-se utilizar a biblioteca matplotlib, que pode ser chamada como abaixo.
#
#
# Alguns métodos que podem ser realizados, estão abaixo aplicados a um grafíco de barras dos valores de controle e com drogas. Muitos métodos disponíveis em: https://www.shanelynn.ie/bar-plots-in-python-using-pandas-dataframes/

# %%
dados['tratamento'].value_counts().plot.bar()

# %%
dados['tratamento'].value_counts().plot.bar(color=['red','blue'])
plt.title("Gráfico de barras para tratamentos")
plt.xlabel("Tipo de tratamento")
plt.ylabel("Quantidade de amostras")
plt.xticks(rotation=0, horizontalalignment="center")
# Out:
# (array([0, 1]), <a list of 2 Text major ticklabel objects>)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.set_title("Gráfico de barras para tratamentos", fontweight="bold", color="#2874A6",fontsize=20)
ax.set_xlabel("Tratamento", fontweight="bold", fontsize="large", color="#566573")
ax.set_ylabel("Quantidade", fontweight="bold", color = "#566573", fontsize="large")


dados_trat = dados['tratamento'].value_counts()

a = dados_trat.loc['com_droga']
b = dados_trat.loc['com_controle']

ax.bar("com droga",a, label="Com droga", color="green")
ax.bar("com controle", b, label="Com controle", color="red") 

plt.legend()

# %%
import matplotlib.pyplot as plt

tipos_de_tratamento = dados['tratamento'].value_counts()

plt.title('Tipos de Tratamento')

def cria_labels_feliz(labels):
  return [label.replace('_',' ').capitalize() for label in labels]


nova_labels =  cria_labels_feliz(dados.tratamento.unique())
  

explode = (0,0.2)
plt.pie(tipos_de_tratamento, labels = nova_labels, shadow = True, explode = explode, autopct= '%1.1f%%')

plt.show()

# %% [markdown]
# ###Desafio 08: Resumo do que você aprendeu com os dados

# %% [markdown]
# Quando ao que foi descoberto aos dados, temos:
#
# Todos os casos com controle foram listados com a aplicação da droga 'cacb2b860' com dose D1 e D2 e tempos praticamente divididos igualiatariamente, imagino que foi feito dessa forma para que não houvesse enviasamento dos dados.
# Com relação aos dados com droga, vemos que há drogas que foram aplicados muito mais vezes, como a droga '87d714366' foi aplicada em mais de 700 amostras, e algumas droga que só foram aplicadas uma vez.
# Para as drogas aplicadas apenas uma vez, tempos que os tempos e os tipos de doses não foram experimentadas de maneira balanceada.

# %% [markdown]
# Se quiser mais informações a base dados estudada na imersão é uma versão simplificada deste desafio do Kaggle (em inglês).
#
# Também recomendamos que você acesse o Connectopedia. O Connectopedia é um dicionário gratuito de termos e conceitos que incluem definições de viabilidade de células e expressão de genes.
#
# O desafio do Kaggle também está relacionado a estes artigos científicos:
#
# Corsello et al. “Discovering the anticancer potential of non-oncology drugs by systematic viability profiling,” Nature Cancer, 2020, https://doi.org/10.1038/s43018-019-0018-6
#
# Subramanian et al. “A Next Generation Connectivity Map: L1000 Platform and the First 1,000,000 Profiles,” Cell, 2017, https://doi.org/10.1016/j.cell.2017.10.049
